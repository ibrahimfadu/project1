# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file=input("Enter the filename: ")
sub=input("Enter the Subject: ")
graph=input("Do yo want graph \n Enter y or n")
print("\n\n")
df=pd.read_csv(file)
print(df.loc[df['Marks']>=75,['Name',sub]])
if graph.lower()=='y':
    plt.barh(df["Name"],df[sub],color='red')
    plt.title("Bar Graph")
    plt.xlabel("Marks")
    plt.ylabel("Name")
else:
    print("\n")
    print("Graph skipped as user input")
# Out:
# Enter the filename:  student_marks.csv
# Enter the Subject:  Marks
# Do yo want graph
#  Enter y or n y
#      Name  Marks
# 1  Suresh     95
# 5    Annu     76
# 7  Ritesh     87
# 8   Farha     89
# 9  Mukesh     77
